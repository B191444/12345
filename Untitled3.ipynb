# %%
import matplotlib.pyplot as plt

# %%
x=[20,20,2,200]
y=[1,2,3,4]

# %%
plt.plot(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.show()

# %%
import numpy as np

# %%
x=np.arange(10,50,0.1)
y=np.sin(x)

# %%
plt.plot(x,y)
plt.show()

# %%
x=
